# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "../cleaned_data/totalBIRD.zip"
bird_data_df = pd.read_csv(csv_file)
bird_data_df
# Out:
#        Species             Common_name          Scientific_name  \
# 0       rocpig             Rock Pigeon            Columba livia
# 1       moudov           Mourning Dove         Zenaida macroura
# 2       annhum      Anna's Hummingbird             Calypte anna
# 3       y00475           American Coot         Fulica americana
# 4       sancra          Sandhill Crane      Antigone canadensis
# ...        ...                     ...                      ...
# 987635  pagplo   Pacific Golden-Plover          Pluvialis fulva
# 987636  issjay        Island Scrub-Jay     Aphelocoma insularis
# 987637  brnthr          Brown Thrasher          Toxostoma rufum
# 987638  crithr        Crissal Thrasher       Toxostoma crissale
# 987639  robgro  Rose-breasted Grosbeak  Pheucticus ludovicianus
#
#                                             location_Name        Date  \
# 0                                                Columbia  2003-01-01
# 1                                                Columbia  2003-01-01
# 2                                                Columbia  2003-01-01
# 3       Woodbridge Ecological Reserve (Isenberg Crane ...  2003-01-01
# 4       Woodbridge Ecological Reserve (Isenberg Crane ...  2003-01-01
# ...                                                   ...         ...
# 987635                      Point Reyes National Seashore  2013-12-31
# 987636                Santa Cruz Island / Limuw (SBA Co.)  2013-12-31
# 987637        Pacific Grove--Bayview Ave @ Cedar vicinity  2013-12-31
# 987638                               Shoshone-Tecopa Area  2013-12-31
# 987639        Pacific Grove--Bayview Ave @ Cedar vicinity  2013-12-31
#
#               LAT         LNG   Time
# 0       38.036320 -120.401030  15:00
# 1       38.036320 -120.401030  15:00
# 2       38.036320 -120.401030  15:00
# 3       38.157692 -121.443740  15:00
# 4       38.157692 -121.443740  15:00
# ...           ...         ...    ...
# 987635  38.043335 -122.802519    NaN
# 987636  34.005339 -119.773813    NaN
# 987637  36.624783 -121.923247    NaN
# 987638  35.866300 -116.271200    NaN
# 987639  36.624783 -121.923247    NaN
#
# [987640 rows x 8 columns]

# %%
import getpass

# %%
pw = getpass.getpass()
# Out:
#  ········

# %%
rds_connection_string = "@localhost:5432/sighting_db"
engine = create_engine(f'postgresql://postgres:{pw}{rds_connection_string}')
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/sighting_db)

# %%
bird_data_df.to_sql(name='bird_data', con=engine, if_exists='fail', index=False)
